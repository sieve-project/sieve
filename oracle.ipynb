# %%
import copy
import kubernetes
import common
import yaml
import json


def get_resource_helper(func):
    k8s_namespace = "default"
    response = func(k8s_namespace, _preload_content=False, watch=False)
    data = json.loads(response.data)
    return [resource for resource in data['items']]

def generate_resources():
    print("Generating cluster resources digest ...")
    kubernetes.config.load_kube_config()
    core_v1 = kubernetes.client.CoreV1Api()
    apps_v1 = kubernetes.client.AppsV1Api()
    resources = {}
    
    resources[common.POD] = get_resource_helper(core_v1.list_namespaced_pod)
    resources[common.PVC] = get_resource_helper(core_v1.list_namespaced_persistent_volume_claim)
    resources[common.DEPLOYMENT] = get_resource_helper(apps_v1.list_namespaced_deployment)
    resources[common.STS] = get_resource_helper(apps_v1.list_namespaced_stateful_set)

    return resources

def generate_resources_old():
    print("Generating cluster resources digest ...")
    kubernetes.config.load_kube_config()
    core_v1 = kubernetes.client.CoreV1Api()
    apps_v1 = kubernetes.client.AppsV1Api()
    k8s_namespace = "default"
    resources = {}
    for ktype in common.KTYPES:
        resources[ktype] = []
    for pod in core_v1.list_namespaced_pod(k8s_namespace, watch=False).items:
        resources[common.POD].append(pod)
    for pvc in core_v1.list_namespaced_persistent_volume_claim(k8s_namespace, watch=False).items:
        resources[common.PVC].append(pvc)
    for dp in apps_v1.list_namespaced_deployment(k8s_namespace, watch=False).items:
        resources[common.DEPLOYMENT].append(dp)
    for sts in apps_v1.list_namespaced_stateful_set(k8s_namespace, watch=False).items:
        resources[common.STS].append(sts)
    return resources

# %%
kubernetes.config.load_kube_config()
core_v1 = kubernetes.client.CoreV1Api()
apps_v1 = kubernetes.client.AppsV1Api()

pods = core_v1.list_namespaced_pod("default", watch=False)
# print(pods.items)

core_v1.api_client.deserialize
apps_v1.get_api_resources()
# Out:
# {'api_version': 'v1',
#  'group_version': 'apps/v1',
#  'kind': 'APIResourceList',
#  'resources': [{'categories': None,
#                 'group': None,
#                 'kind': 'ControllerRevision',
#                 'name': 'controllerrevisions',
#                 'namespaced': True,
#                 'short_names': None,
#                 'singular_name': '',
#                 'storage_version_hash': '85nkx63pcBU=',
#                 'verbs': ['create',
#                           'delete',
#                           'deletecollection',
#                           'get',
#                           'list',
#                           'patch',
#                           'update',
#                           'watch'],
#                 'version': None},
#                {'categories': ['all'],
#                 'group': None,
#                 'kind': 'DaemonSet',
#                 'name': 'daemonsets',
#                 'namespaced': True,
#                 'short_names': ['ds'],
#                 'singular_name': '',
#                 'storage_version_hash': 'dd7pWHUlMKQ=',
#                 'verbs': ['create',
#                           'delete',
#                           'deletecollection',
#                           'get',
#                           'list',
#                           'patch',
#                           'update',
#                           'watch'],
#                 'version': None},
#                {'categories': None,
#                 'group': None,
#                 'kind': 'DaemonSet',
#                 'name': 'daemonsets/status',
#                 'namespaced': True,
#                 'short_names': None,
#                 'singular_name': '',
#                 'storage_version_hash': None,
#                 'verbs': ['get', 'patch', 'update'],
#                 'version': None},
#                {'categories': ['all'],
#                 'group': None,
#                 'kind': 'Deployment',
#                 'name': 'deployments',
#                 'namespaced': True,
#                 'short_names': ['deploy'],
#                 'singular_name': '',
#                 'storage_version_hash': '8aSe+NMegvE=',
#                 'verbs': ['create',
#                           'delete',
#                           'deletecollection',
#                           'get',
#                           'list',
#                           'patch',
#                           'update',
#                           'watch'],
#                 'version': None},
#                {'categories': None,
#                 'group': 'autoscaling',
#                 'kind': 'Scale',
#                 'name': 'deployments/scale',
#                 'namespaced': True,
#                 'short_names': None,
#                 'singular_name': '',
#                 'storage_version_hash': None,
#                 'verbs': ['get', 'patch', 'update'],
#                 'version': 'v1'},
#                {'categories': None,
#                 'group': None,
#                 'kind': 'Deployment',
#                 'name': 'deployments/status',
#                 'namespaced': True,
#                 'short_names': None,
#                 'singular_name': '',
#                 'storage_version_hash': None,
#                 'verbs': ['get', 'patch', 'update'],
#                 'version': None},
#                {'categories': ['all'],
#                 'group': None,
#                 'kind': 'ReplicaSet',
#                 'name': 'replicasets',
#                 'namespaced': True,
#                 'short_names': ['rs'],
#                 'singular_name': '',
#                 'storage_version_hash': 'P1RzHs8/mWQ=',
#                 'verbs': ['create',
#                           'delete',
#                           'deletecollection',
#                           'get',
#                           'list',
#                           'patch',
#                           'update',
#                           'watch'],
#                 'version': None},
#                {'categories': None,
#                 'group': 'autoscaling',
#                 'kind': 'Scale',
#                 'name': 'replicasets/scale',
#                 'namespaced': True,
#                 'short_names': None,
#                 'singular_name': '',
#                 'storage_version_hash': None,
#                 'verbs': ['get', 'patch', 'update'],
#                 'version': 'v1'},
#                {'categories': None,
#                 'group': None,
#                 'kind': 'ReplicaSet',
#                 'name': 'replicasets/status',
#                 'namespaced': True,
#                 'short_names': None,
#                 'singular_name': '',
#                 'storage_version_hash': None,
#                 'verbs': ['get', 'patch', 'update'],
#                 'version': None},
#                {'categories': ['all'],
#                 'group': None,
#                 'kind': 'StatefulSet',
#                 'name': 'statefulsets',
#                 'namespaced': True,
#                 'short_names': ['sts'],
#                 'singular_name': '',
#                 'storage_version_hash': 'H+vl74LkKdo=',
#                 'verbs': ['create',
#                           'delete',
#                           'deletecollection',
#                           'get',
#                           'list',
#                           'patch',
#                           'update',
#                           'watch'],
#                 'version': None},
#                {'categories': None,
#                 'group': 'autoscaling',
#                 'kind': 'Scale',
#                 'name': 'statefulsets/scale',
#                 'namespaced': True,
#                 'short_names': None,
#                 'singular_name': '',
#                 'storage_version_hash': None,
#                 'verbs': ['get', 'patch', 'update'],
#                 'version': 'v1'},
#                {'categories': None,
#                 'group': None,
#                 'kind': 'StatefulSet',
#                 'name': 'statefulsets/status',
#                 'namespaced': True,
#                 'short_names': None,
#                 'singular_name': '',
#                 'storage_version_hash': None,
#                 'verbs': ['get', 'patch', 'update'],
#                 'version': None}]}

# %%
learn2_old = generate_resources_old()
# Out:
# Generating cluster resources digest ...

# %%
test2_old = generate_resources_old()
# Out:
# Generating cluster resources digest ...

# %%
from deepdiff import DeepDiff

DeepDiff(learn2_old, test2_old)
# Out:
# {}

# %%
learn2 = generate_resources()
learn2
open("learn2.json", "w").write(json.dumps(learn2))
# Out:
# Generating cluster resources digest ...
# 80137

# %%
test2 = generate_resources()
test2
open("test2.json", "w").write(json.dumps(test2))
# Out:
# Generating cluster resources digest ...
# 62369

# %%
from types import SimpleNamespace
learn = json.loads(open("learn1.json").read(), object_hook=lambda d: SimpleNamespace(**d))
test = json.loads(open("test1.json").read(), object_hook=lambda d: SimpleNamespace(**d))

learn = json.loads(open("learn1.json").read())
test = json.loads(open("test1.json").read())

# %%
import jsondiff as jd
import copy


not_care_keys = ['uid', 'resourceVersion', 'creationTimestamp', 'ownerReferences', 'managedFields', 'generateName', 'selfLink', 'annotations',
                'pod-template-hash', 'secretName', 'image', 'lastTransitionTime', 'nodeName', 'podIPs', 'hostIP', 'containerID', 'imageID',
                'startTime',' startedAt', 'volumeMounts', 'finishedAt', 'volumeName', 'lastUpdateTime']
not_care = [jd.delete, jd.insert] + not_care_keys + ['name']

def trim_resource(cur):
    if type(cur) is list:
        for item in cur:
            trim_resource(item)
            
    if type(cur) is dict:
        for key in list(cur):
            if key in not_care_keys:
                cur.pop(key, None)
            else:
                trim_resource(cur[key])
                


def look_for_resouces_diff(learn, test):
    learn_trim = copy.deepcopy(learn)
    test_trim = copy.deepcopy(test)
    trim_resource(learn_trim)
    trim_resource(test_trim)
    diff = jd.diff(learn_trim, test_trim, syntax='symmetric')
    
    print(learn_trim)
    
    for rtype in diff:
        print("> diff for", rtype)
        rdiff = diff[rtype]
        # Check for resource delete/insert
        if jd.delete in rdiff:
            # Any resource deleted
            for (idx, item) in rdiff[jd.delete]:
                print("[resource deleted]", item['metadata']['namespace'], item['metadata']['name'], "old status:", item['status']['phase'])


        if jd.insert in rdiff:
            # Any resource added
            for (idx, item) in rdiff[jd.insert]:
                print("[resource added]", item['metadata']['namespace'], item['metadata']['name'], "new status:", item['status']['phase'])

        # Check for resource internal fields
        for idx in rdiff:
            if not type(idx) is int:
                continue
            resource = test[rtype][idx]
            name = resource['metadata']['name']
            namespace = resource['metadata']['namespace']
            item = rdiff[idx]
            # Handle for metadata
            if 'metadata' in item:
                metadata = item['metadata']
                # Also should handle add/delete here
                for key in metadata:
                    if not key in not_care:
                        print("[metadata field changed]", name, key, "changed", "delta: ", metadata[key])
                if jd.delete in metadata:
                    print("[metadata field deleted]", name, metadata[jd.delete])
                if jd.insert in metadata:
                    print("[metadata field added]", name, metadata[jd.insert])

    #             if 'status' in item:
    #                 # Status changed
    #                 print("status changed", item['status'])
        import pprint
        pp = pprint.PrettyPrinter()

        pp.pprint(rdiff)

    
look_for_resouces_diff(learn, test)
# Out:
# {'pod': [{'metadata': {'name': 'cassandra-operator-868569994f-g49w4', 'namespace': 'default', 'labels': {'name': 'cassandra-operator', 'sonartag': 'cassandra-operator'}}, 'spec': {'volumes': [{'name': 'cassandra-operator-token-whdnd', 'secret': {'defaultMode': 420}}], 'containers': [{'name': 'cassandra-operator', 'command': ['./cassandra-operator'], 'envFrom': [{'configMapRef': {'name': 'sonar-testing-global-config'}}], 'env': [{'name': 'WATCH_NAMESPACE', 'valueFrom': {'fieldRef': {'apiVersion': 'v1', 'fieldPath': 'metadata.namespace'}}}, {'name': 'POD_NAME', 'valueFrom': {'fieldRef': {'apiVersion': 'v1', 'fieldPath': 'metadata.name'}}}, {'name': 'OPERATOR_NAME', 'value': 'cassandra-operator'}, {'name': 'KUBERNETES_SERVICE_HOST', 'value': 'kind-control-plane'}, {'name': 'KUBERNETES_SERVICE_PORT', 'value': '6443'}], 'resources': {}, 'terminationMessagePath': '/dev/termination-log', 'terminationMessagePolicy': 'File', 'imagePullPolicy': 'IfNotPresent'}], 'restartPolicy': 'Always', 'terminationGracePeriodSeconds': 30, 'dnsPolicy': 'ClusterFirst', 'serviceAccountName': 'cassandra-operator', 'serviceAccount': 'cassandra-operator', 'securityContext': {}, 'schedulerName': 'default-scheduler', 'tolerations': [{'key': 'node.kubernetes.io/not-ready', 'operator': 'Exists', 'effect': 'NoExecute', 'tolerationSeconds': 300}, {'key': 'node.kubernetes.io/unreachable', 'operator': 'Exists', 'effect': 'NoExecute', 'tolerationSeconds': 300}], 'priority': 0, 'enableServiceLinks': True}, 'status': {'phase': 'Running', 'conditions': [{'type': 'Initialized', 'status': 'True', 'lastProbeTime': None}, {'type': 'Ready', 'status': 'True', 'lastProbeTime': None}, {'type': 'ContainersReady', 'status': 'True', 'lastProbeTime': None}, {'type': 'PodScheduled', 'status': 'True', 'lastProbeTime': None}], 'podIP': '10.244.3.2', 'containerStatuses': [{'name': 'cassandra-operator', 'state': {'running': {'startedAt': '2021-07-31T16:25:39Z'}}, 'lastState': {}, 'ready': True, 'restartCount': 0, 'started': True}], 'qosClass': 'BestEffort'}}, {'metadata': {'name': 'cassandra-test-cluster-dc1-rack1-0', 'namespace': 'default', 'labels': {'app.kubernetes.io/managed-by': 'com.instaclustr.cassandra-operator', 'cassandra-operator.instaclustr.com/cluster': 'test-cluster', 'cassandra-operator.instaclustr.com/datacenter': 'dc1', 'cassandra-operator.instaclustr.com/rack': 'rack1', 'controller-revision-hash': 'cassandra-test-cluster-dc1-rack1-7d8d8dbfc8', 'statefulset.kubernetes.io/pod-name': 'cassandra-test-cluster-dc1-rack1-0'}}, 'spec': {'volumes': [{'name': 'data-volume', 'persistentVolumeClaim': {'claimName': 'data-volume-cassandra-test-cluster-dc1-rack1-0'}}, {'name': 'pod-info', 'downwardAPI': {'items': [{'path': 'labels', 'fieldRef': {'apiVersion': 'v1', 'fieldPath': 'metadata.labels'}}, {'path': 'annotations', 'fieldRef': {'apiVersion': 'v1', 'fieldPath': 'metadata.annotations'}}, {'path': 'namespace', 'fieldRef': {'apiVersion': 'v1', 'fieldPath': 'metadata.namespace'}}, {'path': 'name', 'fieldRef': {'apiVersion': 'v1', 'fieldPath': 'metadata.name'}}], 'defaultMode': 420}}, {'name': 'operator-config-volume', 'configMap': {'name': 'cassandra-test-cluster-dc1-operator-config', 'items': [{'key': 'cassandra_yaml_d_001_operator_overrides_yaml', 'path': 'cassandra.yaml.d/001-operator-overrides.yaml'}, {'key': 'jvm_options_d_001_jvm_memory_gc_options', 'path': 'jvm.options.d/001-jvm-memory-gc.options'}], 'defaultMode': 420}}, {'name': 'operator-rack-config-volume-rack1', 'configMap': {'name': 'cassandra-test-cluster-dc1-rack-config-rack1', 'items': [{'key': 'cassandra_rackdc_properties', 'path': 'cassandra-rackdc.properties'}], 'defaultMode': 420}}, {'name': 'cassandra-performance-token-5drtk', 'secret': {'defaultMode': 420}}], 'initContainers': [{'name': 'sysctl-limits', 'command': ['sh', '-xuec'], 'args': ['sysctl -w vm.max_map_count=1048575'], 'resources': {}, 'terminationMessagePath': '/dev/termination-log', 'terminationMessagePolicy': 'File', 'imagePullPolicy': 'Always',  ...
# > diff for pod
# {0: {'metadata': {'name': ['cassandra-operator-868569994f-g49w4',
#                            'cassandra-operator-7dd4fdc6dd-wmgfz']},
#      'spec': {'containers': {0: {'env': {3: {'value': ['kind-control-plane',
#                                                        'kind-control-plane3']}}}},
#               'volumes': {0: {'name': ['cassandra-operator-token-whdnd',
#                                        'cassandra-operator-token-9rbqc']}}},
#      'status': {'containerStatuses': {0: {'state': {'running': {'startedAt': ['2021-07-31T16:25:39Z',
#                                                                               '2021-07-31T11:43:21Z']}}}},
#                 'podIP': ['10.244.3.2', '10.244.3.7']}},
#  1: {'spec': {'volumes': {4: {'name': ['cassandra-performance-token-5drtk',
#                                        'cassandra-performance-token-kpq4b']}}},
#      'status': {'containerStatuses': {0: {'state': {'running': {'startedAt': ['2021-07-31T16:28:33Z',
#                                                                               '2021-07-31T11:43:08Z']}}},
#                                       1: {'state': {'running': {'startedAt': ['2021-07-31T16:28:34Z',
#                                                                               '2021-07-31T11:43:09Z']}}}},
#                 'initContainerStatuses': {0: {'state': {'terminated': {'startedAt': ['2021-07-31T16:28:31Z',
#                                                                                      '2021-07-31T11:43:06Z']}}}},
#                 'podIP': ['10.244.4.6', '10.244.3.6']}}}
# > diff for persistentvolumeclaim
# [metadata field added] data-volume-cassandra-test-cluster-dc1-rack1-0 {'deletionTimestamp': '2021-07-31T11:43:23Z', 'deletionGracePeriodSeconds': 0}
# {0: {'metadata': {insert: {'deletionGracePeriodSeconds': 0,
#                            'deletionTimestamp': '2021-07-31T11:43:23Z'}}}}
# > diff for deployment
# {0: {'spec': {'template': {'spec': {'containers': {0: {'env': {3: {'value': ['kind-control-plane',
#                                                                              'kind-control-plane3']}}}}}}},
#      'status': {'conditions': {1: {'message': ['ReplicaSet '
#                                                '"cassandra-operator-868569994f" '
#                                                'has successfully progressed.',
#                                                'ReplicaSet '
#                                                '"cassandra-operator-7dd4fdc6dd" '
#                                                'has successfully '
#                                                'progressed.']}}}}}

# %%
from deepdiff import DeepDiff

diff = DeepDiff(learn, test, verbose_level=2)

import pprint
pp = pprint.PrettyPrinter(indent=2)

def output(key):
    print(key)
    pp.pprint(diff[key])
    print()

# output("type_changes")

# output("dictionary_item_added")
# output("dictionary_item_removed")
# output("values_changed")

# print(diff["dictionary_item_added"][0])
diff
# Out:
# {'dictionary_item_added': {'root[\'pod\'][0][\'metadata\'][\'managedFields\'][0][\'fieldsV1\'][\'f:metadata\'][\'f:ownerReferences\'][\'k:{"uid":"7b0e5c31-fa50-4237-88f0-18c0da2f20f1"}\']': {'.': {},
#    'f:apiVersion': {},
#    'f:blockOwnerDeletion': {},
#    'f:controller': {},
#    'f:kind': {},
#    'f:name': {},
#    'f:uid': {}},
#   "root['pod'][0]['metadata']['managedFields'][1]['fieldsV1']['f:status']['f:containerStatuses']": {},
#   "root['pod'][0]['metadata']['managedFields'][1]['fieldsV1']['f:status']['f:hostIP']": {},
#   "root['pod'][0]['metadata']['managedFields'][1]['fieldsV1']['f:status']['f:phase']": {},
#   "root['pod'][0]['metadata']['managedFields'][1]['fieldsV1']['f:status']['f:podIP']": {},
#   "root['pod'][0]['metadata']['managedFields'][1]['fieldsV1']['f:status']['f:podIPs']": {'.': {},
#    'k:{"ip":"10.244.3.7"}': {'.': {}, 'f:ip': {}}},
#   "root['pod'][0]['metadata']['managedFields'][1]['fieldsV1']['f:status']['f:startTime']": {},
#   'root[\'pod\'][0][\'metadata\'][\'managedFields\'][1][\'fieldsV1\'][\'f:status\'][\'f:conditions\'][\'k:{"type":"ContainersReady"}\']': {'.': {},
#    'f:lastProbeTime': {},
#    'f:lastTransitionTime': {},
#    'f:status': {},
#    'f:type': {}},
#   'root[\'pod\'][0][\'metadata\'][\'managedFields\'][1][\'fieldsV1\'][\'f:status\'][\'f:conditions\'][\'k:{"type":"Initialized"}\']': {'.': {},
#    'f:lastProbeTime': {},
#    'f:lastTransitionTime': {},
#    'f:status': {},
#    'f:type': {}},
#   'root[\'pod\'][0][\'metadata\'][\'managedFields\'][1][\'fieldsV1\'][\'f:status\'][\'f:conditions\'][\'k:{"type":"Ready"}\']': {'.': {},
#    'f:lastProbeTime': {},
#    'f:lastTransitionTime': {},
#    'f:status': {},
#    'f:type': {}},
#   'root[\'pod\'][1][\'metadata\'][\'managedFields\'][0][\'fieldsV1\'][\'f:metadata\'][\'f:ownerReferences\'][\'k:{"uid":"097bd429-66c6-497a-b632-3c892c3cbf1d"}\']': {'.': {},
#    'f:apiVersion': {},
#    'f:blockOwnerDeletion': {},
#    'f:controller': {},
#    'f:kind': {},
#    'f:name': {},
#    'f:uid': {}},
#   'root[\'pod\'][1][\'metadata\'][\'managedFields\'][1][\'fieldsV1\'][\'f:status\'][\'f:podIPs\'][\'k:{"ip":"10.244.3.6"}\']': {'.': {},
#    'f:ip': {}},
#   "root['persistentvolumeclaim'][0]['metadata']['deletionTimestamp']": '2021-07-31T11:43:23Z',
#   "root['persistentvolumeclaim'][0]['metadata']['deletionGracePeriodSeconds']": 0,
#   "root['deployment'][0]['metadata']['managedFields'][1]['fieldsV1']['f:metadata']['f:annotations']['.']": {},
#   'root[\'statefulset\'][0][\'metadata\'][\'managedFields\'][0][\'fieldsV1\'][\'f:metadata\'][\'f:ownerReferences\'][\'k:{"uid":"6cb56c1e-2be7-47b0-932a-296e58e56919"}\']': {'.': {},
#    'f:apiVersion': {},
#    'f:blockOwnerDeletion': {},
#    'f:controller': {},
#    'f:kind': {},
#    'f:name': {},
#    'f:uid': {}}},
#  'dictionary_item_removed': {'root[\'pod\'][0][\'metadata\'][\'managedFields\'][0][\'fieldsV1\'][\'f:metadata\'][\'f:ownerReferences\'][\'k:{"uid":"88e232ec-26b2-43c2-a853-af6e0b428a4b"}\']': {'.': {},
#    'f:apiVersion': {},
#    'f:blockOwnerDeletion': {},
#    'f:controller': {},
#    'f:kind': {},
#    'f:name': {},
#    'f:uid': {}},
#   "root['pod'][0]['metadata']['managedFields'][1]['fieldsV1']['f:status']['f:conditions']['.']": {},
#   'root[\'pod\'][0][\'metadata\'][\'managedFields\'][1][\'fieldsV1\'][\'f:status\'][\'f:conditions\'][\'k:{"type":"PodScheduled"}\']': {'.': {},
#    'f:lastProbeTime': {},
#    'f:lastTransitionTime': {},
#    'f:message': {},
#    'f:reason': {},
#    'f:status': {},
#    'f:type': {}},
#   'root[\'pod\'][1][\'metadata\'][\'managedFields\'][0][\'fieldsV1\'][\'f:metadata\'][\'f:ownerReferences\'][\'k:{"uid":"e0210866-b912-4033-9294-d374980295e1"}\']': {'.': {},
#    'f:apiVersion': {},
#    'f:blockOwnerDeletion': {},
#    'f:controller': {},
#    'f:kind': {},
#    'f:name': {},
#    'f:uid': {}},
#   'root[\'pod\'][1][\'metadata\'][\'managedFields\'][1][\'fieldsV1\'][\'f:status\'][\'f:podIPs\'][\'k:{"ip":"10.244.4.6"}\']': {'.': {},
#    'f:ip': {}},
#   "root['deployment'][0]['metadata']['annotations']['kubectl.kubernetes.io/last-applied-configuration']": '{"apiVersion":"apps/v1","kind":"Deployment","metadata":{"annotations":{},"name":"cassandra-operator","namespace":"default"},"spec":{"replicas":1,"selector":{"matchLabels":{"name":"cassandra-operator","sonartag":"cassandra-operator"}},"template":{"metadata":{"labels":{"name":"cassandra-operator","sonartag":"cassandra-operator"}},"spec":{"containers":[{"command":["./cassandra-operator"],"env":[{"name":"WATCH_NAMESPACE","valueFrom":{"fieldRef":{"fieldPath":"metadata.namespace"}}},{"name":"POD_NAME","valueFrom":{"fieldRef":{"fieldPath":"metadata.name"}}},{"name":"OPERATOR_NAME","value":"cassandra-operator"},{"name":"KUBERNETES_SERVICE_HOST","value":"kind-control-plane"},{"name":"KUBERNETES_SERVICE_PORT","value":"6443"}],"envFrom":[{"configMapRef":{"name":"sonar-testing-global-config"}}],"image":"laphets/cassandra-operator:learn","imagePullPolicy":"IfNotPresent","name":"cassandra-operator"}],"serviceAccountName":"cassandra-operator"}}}}\n',
#   "root['deployment'][0]['metadata']['managedFields'][0]['fieldsV1']['f:metadata']": {'f:annotations': {'.': {},
#     'f:kubectl.kubernetes.io/last-applied-configuration': {}}},
#   'root[\'statefulset\'][0][\'metadata\'][\'managedFields\'][0][\'fieldsV1\'][\'f:metadata\'][\'f:ownerReferences\'][\'k:{"uid":"f5ae3344-9942-4b6f-beb7-f8e71da8e8e7"}\']': {'.': {},
#    'f:apiVersion': {},
#    'f:blockOwnerDeletion': {},
#    'f:controller': {},
#    'f:kind': {},
#    'f:name': {},
#    'f:uid': {}}},
#  'values_changed': {"root['pod'][0]['metadata']['name']": {'new_value': 'cassandra-operator-7dd4fdc6dd-wmgfz',
#    'old_value': 'cassandra-operator-868569994f-g49w4'},
#   "root['pod'][0]['metadata']['generateName']": {'new_value': 'cassandra-operator-7dd4fdc6dd-',
#    'old_value': 'cassandra-operator-868569994f-'},
#   "root['pod'][0]['metadata']['selfLink']": {'new_value': '/api/v1/namespaces/default/pods/cassandra-operator-7dd4fdc6dd-wmgfz',
#    'old_value': '/api/v1/namespaces/default/pods/cassandra-operator-868569994f-g49w4'},
#   "root['pod'][0]['metadata']['uid']": {'new_value': 'aea0554b-b67e-47df-a163-894b8887cdc7',
#    'old_value': '2a9b669c-3325-4785-a829-8025b87d35e0'},
#   "root['pod'][0]['metadata']['resourceVersion']": {'new_value': '1841',
#    'old_value': '1021'},
#   "root['pod'][0]['metadata']['creationTimestamp']": {'new_value': '2021-07-31T11:43:20Z',
#    'old_value': '2021-07-31T16:25:22Z'},
#   "root['pod'][0]['metadata']['labels']['pod-template-hash']": {'new_value': '7dd4fdc6dd',
#    'old_value': '868569994f'},
#   "root['pod'][0]['metadata']['ownerReferences'][0]['name']": {'new_value': 'cassandra-operator-7dd4fdc6dd',
#    'old_value': 'cassandra-operator-868569994f'},
#   "root['pod'][0]['metadata']['ownerReferences'][0]['uid']": {'new_value': '7b0e5c31-fa50-4237-88f0-18c0da2f20f1',
#    'old_value': '88e232ec-26b2-43c2-a853-af6e0b428a4b'},
#   "root['pod'][0]['metadata']['managedFields'][0]['time']": {'new_value': '2021-07-31T11:43:20Z',
#    'old_value': '2021-07-31T16:25:22Z'},
#   "root['pod'][0]['metadata']['managedFields'][1]['manager']": {'new_value': 'kubelet',
#    'old_value': 'kube-scheduler'},
#   "root['pod'][0]['metadata']['managedFields'][1]['time']": {'new_value': '2021-07-31T11:43:21Z',
#    'old_value': '2021-07-31T16:25:22Z'},
#   "root['pod'][0]['spec']['volumes'][0]['name']": {'new_value': 'cassandra-operator-token-9rbqc',
#    'old_value': 'cassandra-operator-token-whdnd'},
#   "root['pod'][0]['spec']['volumes'][0]['secret']['secretName']": {'new_value': 'cassandra-operator-token-9rbqc',
#    'old_value': 'cassandra-operator-token-whdnd'},
#   "root['pod'][0]['spec']['containers'][0]['image']": {'new_value': 'laphets/cassandra-operator:time-travel',
#    'old_value': 'laphets/cassandra-operator:learn'},
#   "root['pod'][0]['spec']['containers'][0]['env'][3]['value']": {'new_value': 'kind-control-plane3',
#    'old_value': 'kind-control-plane'},
#   "root['pod'][0]['spec']['containers'][0]['volumeMounts'][0]['name']": {'new_value': 'cassandra-operator-token-9rbqc',
#    'old_value': 'cassandra-operator-token-whdnd'},
#   "root['pod'][0]['status']['conditions'][0]['lastTransitionTime']": {'new_value': '2021-07-31T11:43:20Z',
#    'old_value': '2021-07-31T16:25:38Z'},
#   "root['pod'][0]['status']['conditions'][1]['lastTransitionTime']": {'new_value': '2021-07-31T11:43:21Z',
#    'old_value': '2021-07-31T16:25:40Z'},
#   "root['pod'][0]['status']['conditions'][2]['lastTransitionTime']": {'new_value': '2021-07-31T11:43:21Z',
#    'old_value': '2021-07-31T16:25:40Z'},
#   "root['pod'][0]['status']['conditions'][3]['lastTransitionTime']": {'new_value': '2021-07-31T11:43:20Z',
#    'old_value': '2021-07-31T16:25:38Z'},
#   "root['pod'][0]['status']['hostIP']": {'new_value': '172.18.0.3',
#    'old_value': '172.18.0.7'},
#   "root['pod'][0]['status']['podIP']": {'new_value': '10.244.3.7',
#    'old_value': '10.244.3.2'},
#   "root['pod'][0]['status']['podIPs'][0]['ip']": {'new_value': '10.244.3.7',
#    'old_value': '10.244.3.2'},
#   "root['pod'][0]['status']['startTime']": {'new_value': '2021-07-31T11:43:20Z',
#    'old_value': '2021-07-31T16:25:38Z'},
#   "root['pod'][0]['status']['containerStatuses'][0]['state']['running']['startedAt']": {'new_value': '2021-07-31T11:43:21Z',
#    'old_value': '2021-07-31T16:25:39Z'},
#   "root['pod'][0]['status']['containerStatuses'][0]['image']": {'new_value': 'docker.io/laphets/cassandra-operator:time-travel',
#    'old_value': 'docker.io/laphets/cassandra-operator:learn'},
#   "root['pod'][0]['status']['containerStatuses'][0]['imageID']": {'new_value': 'sha256:aaf5b7aa35766e5d80ee15e5be26deee033d9dce04dc524cbcea4817fa5d2593',
#    'old_value': 'sha256:6519b22725242c5c45a0bba7b3c3a16ff0803eecffd306bd5ad74b78ca6237f2'},
#   "root['pod'][0]['status']['containerStatuses'][0]['containerID']": {'new_value': 'containerd://a0f946d56f326637bdeb2c0562bb93b2b1bac485519b256d9aed8688f3d230fa',
#    'old_value': 'containerd://7e85998a7ddaf3ab21907718e3e8e14aef0bad3e25979b65376eaaeec6def710'},
#   "root['pod'][1]['metadata']['uid']": {'new_value': 'fe69da55-d333-4a5d-94fe-12cf6ba24679',
#    'old_value': 'c7926e8e-a627-4202-a085-90ca6225e36e'},
#   "root['pod'][1]['metadata']['resourceVersion']": {'new_value': '2070',
#    'old_value': '2034'},
#   "root['pod'][1]['metadata']['creationTimestamp']": {'new_value': '2021-07-31T11:43:01Z',
#    'old_value': '2021-07-31T16:28:25Z'},
#   "root['pod'][1]['metadata']['ownerReferences'][0]['uid']": {'new_value': '097bd429-66c6-497a-b632-3c892c3cbf1d',
#    'old_value': 'e0210866-b912-4033-9294-d374980295e1'},
#   "root['pod'][1]['metadata']['managedFields'][0]['time']": {'new_value': '2021-07-31T11:43:01Z',
#    'old_value': '2021-07-31T16:28:25Z'},
#   "root['pod'][1]['metadata']['managedFields'][1]['time']": {'new_value': '2021-07-31T11:44:23Z',
#    'old_value': '2021-07-31T16:29:48Z'},
#   "root['pod'][1]['spec']['volumes'][4]['name']": {'new_value': 'cassandra-performance-token-kpq4b',
#    'old_value': 'cassandra-performance-token-5drtk'},
#   "root['pod'][1]['spec']['volumes'][4]['secret']['secretName']": {'new_value': 'cassandra-performance-token-kpq4b',
#    'old_value': 'cassandra-performance-token-5drtk'},
#   "root['pod'][1]['spec']['initContainers'][0]['volumeMounts'][0]['name']": {'new_value': 'cassandra-performance-token-kpq4b',
#    'old_value': 'cassandra-performance-token-5drtk'},
#   "root['pod'][1]['spec']['containers'][0]['volumeMounts'][3]['name']": {'new_value': 'cassandra-performance-token-kpq4b',
#    'old_value': 'cassandra-performance-token-5drtk'},
#   "root['pod'][1]['spec']['containers'][1]['volumeMounts'][3]['name']": {'new_value': 'cassandra-performance-token-kpq4b',
#    'old_value': 'cassandra-performance-token-5drtk'},
#   "root['pod'][1]['spec']['nodeName']": {'new_value': 'kind-worker2',
#    'old_value': 'kind-worker'},
#   "root['pod'][1]['status']['conditions'][0]['lastTransitionTime']": {'new_value': '2021-07-31T11:43:07Z',
#    'old_value': '2021-07-31T16:28:32Z'},
#   "root['pod'][1]['status']['conditions'][1]['lastTransitionTime']": {'new_value': '2021-07-31T11:44:23Z',
#    'old_value': '2021-07-31T16:29:48Z'},
#   "root['pod'][1]['status']['conditions'][2]['lastTransitionTime']": {'new_value': '2021-07-31T11:44:23Z',
#    'old_value': '2021-07-31T16:29:48Z'},
#   "root['pod'][1]['status']['conditions'][3]['lastTransitionTime']": {'new_value': '2021-07-31T11:43:04Z',
#    'old_value': '2021-07-31T16:28:28Z'},
#   "root['pod'][1]['status']['hostIP']": {'new_value': '172.18.0.3',
#    'old_value': '172.18.0.5'},
#   "root['pod'][1]['status']['podIP']": {'new_value': '10.244.3.6',
#    'old_value': '10.244.4.6'},
#   "root['pod'][1]['status']['podIPs'][0]['ip']": {'new_value': '10.244.3.6',
#    'old_value': '10.244.4.6'},
#   "root['pod'][1]['status']['startTime']": {'new_value': '2021-07-31T11:43:04Z',
#    'old_value': '2021-07-31T16:28:28Z'},
#   "root['pod'][1]['status']['initContainerStatuses'][0]['state']['terminated']['startedAt']": {'new_value': '2021-07-31T11:43:06Z',
#    'old_value': '2021-07-31T16:28:31Z'},
#   "root['pod'][1]['status']['initContainerStatuses'][0]['state']['terminated']['finishedAt']": {'new_value': '2021-07-31T11:43:06Z',
#    'old_value': '2021-07-31T16:28:31Z'},
#   "root['pod'][1]['status']['initContainerStatuses'][0]['state']['terminated']['containerID']": {'new_value': 'containerd://173b5547f99ad683673e8e9cf90b9f61305c0175fe5c64ac3a8a4620b9c96081',
#    'old_value': 'containerd://896d08807ddc07ae6cbee760eef18cf5bb6b3f16a7aa4ac542b9d9b962d3bed6'},
#   "root['pod'][1]['status']['initContainerStatuses'][0]['containerID']": {'new_value': 'containerd://173b5547f99ad683673e8e9cf90b9f61305c0175fe5c64ac3a8a4620b9c96081',
#    'old_value': 'containerd://896d08807ddc07ae6cbee760eef18cf5bb6b3f16a7aa4ac542b9d9b962d3bed6'},
#   "root['pod'][1]['status']['containerStatuses'][0]['state']['running']['startedAt']": {'new_value': '2021-07-31T11:43:08Z',
#    'old_value': '2021-07-31T16:28:33Z'},
#   "root['pod'][1]['status']['containerStatuses'][0]['containerID']": {'new_value': 'containerd://51d20b495e30d75f07c2031e61bf62937a5907f8446d64e37cae9bfe2122e310',
#    'old_value': 'containerd://9c74844664e44a1e0d237789f86bbc6e134c69cea5b9c02497ef4c6f5144f911'},
#   "root['pod'][1]['status']['containerStatuses'][1]['state']['running']['startedAt']": {'new_value': '2021-07-31T11:43:09Z',
#    'old_value': '2021-07-31T16:28:34Z'},
#   "root['pod'][1]['status']['containerStatuses'][1]['containerID']": {'new_value': 'containerd://024d2ec79a5e364eaf93d23ad4345d50e0855187c4af075758d5644b41ea689f',
#    'old_value': 'containerd://15940e58138669bdc0a18f2dbe97f4f6ce5616be74e9531e050f9e3c57c66679'},
#   "root['persistentvolumeclaim'][0]['metadata']['uid']": {'new_value': '726cd5b2-22c1-4fd6-8504-024fd3f21bfa',
#    'old_value': 'b6be7465-b703-4003-b827-86ca77e516b0'},
#   "root['persistentvolumeclaim'][0]['metadata']['resourceVersion']": {'new_value': '1855',
#    'old_value': '1741'},
#   "root['persistentvolumeclaim'][0]['metadata']['creationTimestamp']": {'new_value': '2021-07-31T11:43:01Z',
#    'old_value': '2021-07-31T16:28:25Z'},
#   "root['persistentvolumeclaim'][0]['metadata']['annotations']['volume.kubernetes.io/selected-node']": {'new_value': 'kind-worker2',
#    'old_value': 'kind-worker'},
#   "root['persistentvolumeclaim'][0]['metadata']['managedFields'][0]['time']": {'new_value': '2021-07-31T11:43:01Z',
#    'old_value': '2021-07-31T16:28:25Z'},
#   "root['persistentvolumeclaim'][0]['metadata']['managedFields'][1]['time']": {'new_value': '2021-07-31T11:43:03Z',
#    'old_value': '2021-07-31T16:28:28Z'},
#   "root['persistentvolumeclaim'][0]['spec']['volumeName']": {'new_value': 'pvc-726cd5b2-22c1-4fd6-8504-024fd3f21bfa',
#    'old_value': 'pvc-b6be7465-b703-4003-b827-86ca77e516b0'},
#   "root['deployment'][0]['metadata']['uid']": {'new_value': '0aa25c4a-97b9-49c5-9ad5-60d28fd88c7f',
#    'old_value': '6558fac0-8cac-4f7e-88a6-b043d82af774'},
#   "root['deployment'][0]['metadata']['resourceVersion']": {'new_value': '1843',
#    'old_value': '1023'},
#   "root['deployment'][0]['metadata']['creationTimestamp']": {'new_value': '2021-07-31T11:43:20Z',
#    'old_value': '2021-07-31T16:25:21Z'},
#   "root['deployment'][0]['metadata']['managedFields'][0]['manager']": {'new_value': 'sonar-server',
#    'old_value': 'kubectl-client-side-apply'},
#   "root['deployment'][0]['metadata']['managedFields'][0]['time']": {'new_value': '2021-07-31T11:43:20Z',
#    'old_value': '2021-07-31T16:25:21Z'},
#   "root['deployment'][0]['metadata']['managedFields'][1]['time']": {'new_value': '2021-07-31T11:43:21Z',
#    'old_value': '2021-07-31T16:25:40Z'},
#   "root['deployment'][0]['spec']['template']['spec']['containers'][0]['image']": {'new_value': 'laphets/cassandra-operator:time-travel',
#    'old_value': 'laphets/cassandra-operator:learn'},
#   "root['deployment'][0]['spec']['template']['spec']['containers'][0]['env'][3]['value']": {'new_value': 'kind-control-plane3',
#    'old_value': 'kind-control-plane'},
#   "root['deployment'][0]['status']['conditions'][0]['lastUpdateTime']": {'new_value': '2021-07-31T11:43:21Z',
#    'old_value': '2021-07-31T16:25:40Z'},
#   "root['deployment'][0]['status']['conditions'][0]['lastTransitionTime']": {'new_value': '2021-07-31T11:43:21Z',
#    'old_value': '2021-07-31T16:25:40Z'},
#   "root['deployment'][0]['status']['conditions'][1]['lastUpdateTime']": {'new_value': '2021-07-31T11:43:21Z',
#    'old_value': '2021-07-31T16:25:40Z'},
#   "root['deployment'][0]['status']['conditions'][1]['lastTransitionTime']": {'new_value': '2021-07-31T11:43:20Z',
#    'old_value': '2021-07-31T16:25:21Z'},
#   "root['deployment'][0]['status']['conditions'][1]['message']": {'new_value': 'ReplicaSet "cassandra-operator-7dd4fdc6dd" has successfully progressed.',
#    'old_value': 'ReplicaSet "cassandra-operator-868569994f" has successfully progressed.'},
#   "root['statefulset'][0]['metadata']['uid']": {'new_value': '097bd429-66c6-497a-b632-3c892c3cbf1d',
#    'old_value': 'e0210866-b912-4033-9294-d374980295e1'},
#   "root['statefulset'][0]['metadata']['resourceVersion']": {'new_value': '2075',
#    'old_value': '2039'},
#   "root['statefulset'][0]['metadata']['creationTimestamp']": {'new_value': '2021-07-31T11:43:01Z',
#    'old_value': '2021-07-31T16:28:25Z'},
#   "root['statefulset'][0]['metadata']['ownerReferences'][0]['uid']": {'new_value': '6cb56c1e-2be7-47b0-932a-296e58e56919',
#    'old_value': 'f5ae3344-9942-4b6f-beb7-f8e71da8e8e7'},
#   "root['statefulset'][0]['metadata']['managedFields'][0]['time']": {'new_value': '2021-07-31T11:43:01Z',
#    'old_value': '2021-07-31T16:28:25Z'},
#   "root['statefulset'][0]['metadata']['managedFields'][1]['time']": {'new_value': '2021-07-31T11:44:23Z',
#    'old_value': '2021-07-31T16:29:48Z'}},
#  'iterable_item_removed': {"root['pod'][0]['metadata']['managedFields'][2]": {'manager': 'kubelet',
#    'operation': 'Update',
#    'apiVersion': 'v1',
#    'time': '2021-07-31T16:25:40Z',
#    'fieldsType': 'FieldsV1',
#    'fieldsV1': {'f:status': {'f:conditions': {'k:{"type":"ContainersReady"}': {'.': {},
#        'f:lastProbeTime': {},
#        'f:lastTransitionTime': {},
#        'f:status': {},
#        'f:type': {}},
#       'k:{"type":"Initialized"}': {'.': {},
#        'f:lastProbeTime': {},
#        'f:lastTransitionTime': {},
#        'f:status': {},
#        'f:type': {}},
#       'k:{"type":"Ready"}': {'.': {},
#        'f:lastProbeTime': {},
#        'f:lastTransitionTime': {},
#        'f:status': {},
#        'f:type': {}}},
#      'f:containerStatuses': {},
#      'f:hostIP': {},
#      'f:phase': {},
#      'f:podIP': {},
#      'f:podIPs': {'.': {}, 'k:{"ip":"10.244.3.2"}': {'.': {}, 'f:ip': {}}},
#      'f:startTime': {}}}}}}

# %%
diff['dictionary_item_removed'].keys()
# Out:
# dict_keys(['root[\'pod\'][0][\'metadata\'][\'managedFields\'][0][\'fieldsV1\'][\'f:metadata\'][\'f:ownerReferences\'][\'k:{"uid":"88e232ec-26b2-43c2-a853-af6e0b428a4b"}\']', "root['pod'][0]['metadata']['managedFields'][1]['fieldsV1']['f:status']['f:conditions']['.']", 'root[\'pod\'][0][\'metadata\'][\'managedFields\'][1][\'fieldsV1\'][\'f:status\'][\'f:conditions\'][\'k:{"type":"PodScheduled"}\']', 'root[\'pod\'][1][\'metadata\'][\'managedFields\'][0][\'fieldsV1\'][\'f:metadata\'][\'f:ownerReferences\'][\'k:{"uid":"e0210866-b912-4033-9294-d374980295e1"}\']', 'root[\'pod\'][1][\'metadata\'][\'managedFields\'][1][\'fieldsV1\'][\'f:status\'][\'f:podIPs\'][\'k:{"ip":"10.244.4.6"}\']', "root['deployment'][0]['metadata']['annotations']['kubectl.kubernetes.io/last-applied-configuration']", "root['deployment'][0]['metadata']['managedFields'][0]['fieldsV1']['f:metadata']", 'root[\'statefulset\'][0][\'metadata\'][\'managedFields\'][0][\'fieldsV1\'][\'f:metadata\'][\'f:ownerReferences\'][\'k:{"uid":"f5ae3344-9942-4b6f-beb7-f8e71da8e8e7"}\']'])
